# %%
import numpy  as np
import pandas as pd

# %%
data = pd.read_csv('train.csv')

# %%
data.shape
# Out:
# (2000, 21)

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
x = data.iloc[:, :-1] # Contains all Features
y = data.iloc[:, -1]  # Contains the Target Variable

# %%
x.shape
# Out:
# (2000, 20)

# %%
mu = x.mean(axis=0)
sigma = x.std(axis=0)
x = (x - mu) / sigma

# %%
from sklearn.feature_selection import SelectKBest

# %%
bestfeatures = SelectKBest()
fit = bestfeatures.fit(x,y)

# %%
fit.scores_
# Out:
# array([3.15981575e+01, 4.76767709e-01, 4.93707801e-01, 4.28239286e-01,
#        7.72181960e-01, 1.05952453e+00, 2.92299608e+00, 1.50068244e+00,
#        3.59431819e+00, 2.62541515e+00, 8.25446358e-01, 1.94848418e+01,
#        2.26208825e+01, 3.52011082e+03, 2.22598374e+00, 1.67099983e+00,
#        1.62881131e+00, 4.57319750e-01, 1.29330223e+00, 2.84940470e-01])

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

# %%
featuresScores = pd.concat([dfcolumns,dfscores],axis=1)
featuresScores.columns = ['Feature','Score']

# %%
featuresScores
# Out:
#           Feature        Score
# 0   battery_power    31.598158
# 1            blue     0.476768
# 2     clock_speed     0.493708
# 3        dual_sim     0.428239
# 4              fc     0.772182
# 5          four_g     1.059525
# 6      int_memory     2.922996
# 7           m_dep     1.500682
# 8       mobile_wt     3.594318
# 9         n_cores     2.625415
# 10             pc     0.825446
# 11      px_height    19.484842
# 12       px_width    22.620882
# 13            ram  3520.110824
# 14           sc_h     2.225984
# 15           sc_w     1.671000
# 16      talk_time     1.628811
# 17        three_g     0.457320
# 18   touch_screen     1.293302
# 19           wifi     0.284940

# %%
featuresScores = featuresScores.sort_values(by='Score', ascending=False)

# %% [markdown]
# Lets take top 10 features

# %%
top10 = list(featuresScores[:10]['Feature'].values)
top10
# Out:
# ['ram',
#  'battery_power',
#  'px_width',
#  'px_height',
#  'mobile_wt',
#  'int_memory',
#  'n_cores',
#  'sc_h',
#  'sc_w',
#  'talk_time']

# %%
#Model Comparison
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
model = make_pipeline(
    StandardScaler(),
    LogisticRegression(max_iter=1000)
)
model.fit(x, y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(max_iter=1000))])

# %%
scores = cross_val_score(model, x, y, cv=10)
scores.mean()
# Out:
# np.float64(0.9620000000000001)

# %% [markdown]
# Now use only top 10 features

# %%
scores = cross_val_score(model, x[top10], y, cv=10)
scores.mean()
# Out:
# np.float64(0.9710000000000001)

# %% [markdown]
# Scores improve here
